# %%
import pandas as pd
import numpy as np
import lightgbm as lgb
from sklearn.model_selection import train_test_split
from sklearn.metrics import mean_absolute_error
import warnings
import re
warnings.filterwarnings('ignore')

# Set display options
pd.set_option('display.float_format', '{:,.4f}'.format)
pd.set_option('display.max_rows', 80)

df = pd.read_csv("car_age_0_updated_dataset.csv", low_memory=False)
print(f"Initial shape: {df.shape}")

counts = df['od_claim_count'].value_counts().sort_index()
print(counts)

df['policy_start_date'] = pd.to_datetime(df['policy_start_date'])
start_date = df['policy_start_date'].min()
end_date = df['policy_start_date'].max()

print(f"Start date: {start_date}")
print(f"End date:   {end_date}")

print("\n Data Types")
with pd.option_context('display.max_rows', None):
    df.info()

print("\n Top Missing Value Columns")
missing_percent = (df.isnull().sum() / len(df)) * 100
print(missing_percent.sort_values(ascending=False).head(15))

print("\n Numerical Feature Summary")
with pd.option_context('display.max_rows', None, 'display.float_format', '{:,.2f}'.format):
    print(df.describe(include='number').transpose())
# Out:
# Initial shape: (82994, 57)
# od_claim_count
# 0.0000    61784
# 1.0000    15169
# 2.0000     4498
# 3.0000     1092
# 4.0000      315
# 5.0000       85
# 6.0000       31
# 7.0000       11
# 8.0000        6
# 9.0000        3
# Name: count, dtype: int64
# Start date: 2018-09-10 00:00:00
# End date:   2025-09-30 00:00:00
#
#  Data Types
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 82994 entries, 0 to 82993
# Data columns (total 57 columns):
#  #   Column                      Non-Null Count  Dtype
# ---  ------                      --------------  -----
#  0   Unnamed: 0                  82994 non-null  int64
#  1   base_policy                 82994 non-null  object
#  2   od_claim_count              82994 non-null  float64
#  3   car_age                     82994 non-null  float64
#  4   experian_rank_final         77375 non-null  float64
#  5   quarterly_service           37 non-null     float64
#  6   pps_mapped                  81321 non-null  float64
#  7   normalized_ncb              82994 non-null  float64
#  8   variant_bracket_mapped      32155 non-null  float64
#  9   daily_commute               259 non-null    float64
#  10  cc_group_ordinal            82994 non-null  float64
#  11  customer_age_group_ordinal  76762 non-null  float64
#  12  hit_flag_service            33177 non-null  float64
#  13  personal_loan_flag          71654 non-null  float64
#  14  pucc_expiry_flag            394 non-null    float64
#  15  embedded_red_flag           41152 non-null  float64
#  16  is_rsa                      81692 non-null  float64
#  17  is_ncb_protect              81692 non-null  float64
#  18  recommended_idv             82994 non-null  float64
#  19  ownership_count             2640 non-null   float64
#  20  ex_showroom_price           82994 non-null  float64
#  21  corrected_body_type         77605 non-null  object
#  22  fuel_type                   82994 non-null  object
#  23  transmission_type           82994 non-null  object
#  24  device_vendor_category      65222 non-null  object
#  25  city_mapped                 82994 non-null  object
#  26  insurer_category            6 non-null      object
#  27  Product_Type2               82994 non-null  object
#  28  Plan_Type                   82994 non-null  object
#  29  make_mapped                 82994 non-null  object
#  30  policy_start_date           82994 non-null  datetime64[ns]
#  31  base_cover_ncb              82994 non-null  float64
#  32  model                       82994 non-null  object
#  33  variant_bracket             32155 non-null  object
#  34  cc_group                    82994 non-null  object
#  35  exposure                    82994 non-null  float64
#  36  customer_age_group          76659 non-null  object
#  37  customer_age                76762 non-null  float64
#  38  exposure_calculated         82994 non-null  float64
#  39  Product+Plan                82994 non-null  object
#  40  cc                          82994 non-null  int64
#  41  policy_start_year           82994 non-null  int64
#  42  policy_start_month          82994 non-null  int64
#  43  policy_start_period         82994 non-null  object
#  44  user_agent                  78732 non-null  object
#  45  make                        82994 non-null  object
#  46  previous_insurer            6 non-null      object
#  47  previous_policy_status      0 non-null      float64
#  48  policy_created_on           82994 non-null  object
#  49  registration_number         2770 non-null   object
#  50  intermediary_id             82994 non-null  int64
#  51  plan_id                     82994 non-null  object
#  52  renewal                     82994 non-null  bool
#  53  is_filtered_policy          82994 non-null  float64
#  54  Status2                     82994 non-null  object
#  55  previous_policy_expired     82970 non-null  object
#  56  recommended_idv_grouped     82994 non-null  object
# dtypes: bool(1), datetime64[ns](1), float64(25), int64(5), object(25)
# memory usage: 35.5+ MB
#
#  Top Missing Value Columns
# previous_policy_status   100.0000
# previous_insurer          99.9928
# insurer_category          99.9928
# quarterly_service         99.9554
# daily_commute             99.6879
# pucc_expiry_flag          99.5253
# ownership_count           96.8190
# registration_number       96.6624
# variant_bracket           61.2562
# variant_bracket_mapped    61.2562
# hit_flag_service          60.0248
# embedded_red_flag         50.4157
# device_vendor_category    21.4136
# personal_loan_flag        13.6636
# customer_age_group         7.6331
# dtype: float64
#
#  Numerical Feature Summary
#                                count         mean        std        min  \
# Unnamed: 0                 82,994.00    42,941.46  25,098.08       0.00
# od_claim_count             82,994.00         0.36       0.71       0.00
# car_age                    82,994.00         0.00       0.00       0.00
# experian_rank_final        77,375.00         5.54       1.30       2.00
# quarterly_service              37.00         7.21      16.09       0.18
# pps_mapped                 81,321.00         1.00       0.00       1.00
# normalized_ncb             82,994.00         0.00       0.00       0.00
# variant_bracket_mapped     32,155.00         2.18       0.77       1.00
# daily_commute                 259.00        38.18      29.93       0.60
# cc_group_ordinal           82,994.00         1.47       0.95       0.00
# customer_age_group_ordinal 76,762.00         1.62       0.82       0.00
# hit_flag_service           33,177.00         0.01       0.09       0.00
# personal_loan_flag         71,654.00         0.48       0.50       0.00
# pucc_expiry_flag              394.00         0.01       0.09       0.00
# embedded_red_flag          41,152.00         0.68       0.47       0.00
# is_rsa                     81,692.00         0.81       0.39       0.00
# is_ncb_protect             81,692.00         0.00       0.00       0.00
# recommended_idv            82,994.00   902,339.05 733,512.41       0.00
# ownership_count             2,640.00         1.00       0.00       1.00
# ex_showroom_price          82,994.00 1,209,182.15 585,386.76 245,500.00
# base_cover_ncb             82,994.00         0.00       0.00       0.00
# exposure                   82,994.00         0.89       0.24       0.00
# customer_age               76,762.00        38.82      10.01      18.00
# exposure_calculated        82,994.00         0.89       0.24       0.00
# cc                         82,994.00    10,964.74  35,595.43       0.00
# policy_start_year          82,994.00     2,023.08       1.55   2,018.00
# policy_start_month         82,994.00         6.61       3.56       1.00
# previous_policy_status          0.00          NaN        NaN        NaN
# intermediary_id            82,994.00       182.30     159.95      31.00
# is_filtered_policy         82,994.00         0.00       0.00       0.00
#
#                                   25%          50%          75%           max
# Unnamed: 0                  21,219.25    42,687.50    64,248.75     88,414.00
# od_claim_count                   0.00         0.00         1.00          9.00
# car_age                          0.00         0.00         0.00          0.00
# experian_rank_final              5.00         6.00         7.00          7.00
# quarterly_service                0.88         1.64         5.07         91.25
# pps_mapped                       1.00         1.00         1.00          1.00
# normalized_ncb                   0.00         0.00         0.00          0.00
# variant_bracket_mapped           2.00         2.00         3.00          3.00
# daily_commute                   18.35        32.86        47.47        280.71
# cc_group_ordinal                 1.00         1.00         2.00          3.00
# customer_age_group_ordinal       1.00         2.00         2.00          3.00
# hit_flag_service                 0.00         0.00         0.00          1.00
# personal_loan_flag               0.00         0.00         1.00          1.00
# pucc_expiry_flag                 0.00         0.00         0.00          1.00
# embedded_red_flag                0.00         1.00         1.00          1.00
# is_rsa                           1.00         1.00         1.00          1.00
# is_ncb_protect                   0.00         0.00         0.00          0.00
# recommended_idv                  0.00   868,300.00 1,360,400.00 11,495,000.00
# ownership_count                  1.00         1.00         1.00          1.00
# ex_showroom_price          799,000.00 1,049,000.00 1,499,000.00 12,100,000.00
# base_cover_ncb                   0.00         0.00         0.00          0.00
# exposure                         0.99         1.00         1.00          1.08
# customer_age                    32.00        37.00        44.00         80.00
# exposure_calculated              0.99         1.00         1.00          1.00
# cc                           1,197.00     1,199.00     1,497.00    903,253.00
# policy_start_year            2,022.00     2,023.00     2,024.00      2,025.00
# policy_start_month               3.00         7.00        10.00         12.00
# previous_policy_status            NaN          NaN          NaN           NaN
# intermediary_id                 64.00       218.00       218.00      1,213.00
# is_filtered_policy               0.00         0.00         0.00          0.00

# %%
# 1. Preprocessing + Feature Engineering

# 1a. Drop columns
missing_percent = (df.isnull().sum() / len(df)) * 100
cols_mostly_empty = missing_percent[missing_percent > 70].index.tolist()
unique_counts = df.nunique()
cols_single_value = unique_counts[unique_counts == 1].index.tolist()

cols_to_drop = list(set(cols_mostly_empty + cols_single_value))

cols_to_drop.extend([
    'Unnamed: 0', 
    'policy_start_period', 
    'policy_start_year', 
    'user_agent', 
    'device_vendor_category',
    'base_policy',           
    'recommended_idv',
    'previous_policy_expired',
    'policy_start_month',
    'policy_created_on',
    'cc',
    'model',
    'make',
    'ex_showroom_price',
    'customer_age',
    'exposure_calculated', 
    'variant_bracket',
    'customer_age_group_ordinal',
    'is_rsa',
    'intermediary_id', 
    'Status2'
])

key_cols = ['od_claim_count', 'exposure', 'policy_start_date']
cols_to_drop = [col for col in cols_to_drop if col not in key_cols]

df_cleaned = df.drop(columns=cols_to_drop)
print(f"Shape after dropping columns: {df_cleaned.shape}")

# 1b. Sanitize Feature Names
original_cols = df_cleaned.columns.tolist()
sanitized_cols = [re.sub(r'[^A-Za-z0-9_]+', '_', col) for col in original_cols]
df_cleaned.columns = sanitized_cols

renamed_cols_dict = {orig: new for orig, new in zip(original_cols, sanitized_cols) if orig != new}
if renamed_cols_dict:
    print("Renamed columns:")
    for orig, new in renamed_cols_dict.items():
        print(f"  '{orig}'  =>  '{new}'")

# 1c. Handle date Column
DATE_COL_NAME = 'policy_start_date'
df_cleaned[DATE_COL_NAME] = pd.to_datetime(df_cleaned[DATE_COL_NAME])

# 1d. Define Feature, Target, and Weight
TARGET = 'od_claim_count'
WEIGHT = 'exposure'
DATE_COL = 'policy_start_date'
features = [col for col in df_cleaned.columns if col not in [TARGET, WEIGHT, DATE_COL]]

# 1e. Handle Categorical Features & NaNs
categorical_features = df_cleaned[features].select_dtypes(include=['object', 'category']).columns.tolist()

for col in categorical_features:
    df_cleaned[col] = df_cleaned[col].astype('category')

# 1f. Print Feature Lists
print(f"\nFinal Features for Model Training ({len(features)})")
numerical_features = df_cleaned[features].select_dtypes(include=np.number).columns.tolist()
print(f"\nNumerical Features ({len(numerical_features)}):")
for col in numerical_features:
    print(f"  - {col}")

print(f"\nCategorical Features ({len(categorical_features)}):")
for col in categorical_features:
    print(f"  - {col}")

# 1g. Feature Cardinality
print("\n Feature Cardinality")

cardinality = df_cleaned[features].nunique().sort_values(ascending=False)

print("Features with the most unique values:")
with pd.option_context('display.max_rows', 30):
    print(cardinality.head(30))

# Identify high-cardinality categorical features
high_card_cols = [
    col for col in categorical_features 
    if df_cleaned[col].nunique() > 50
]
# Out:
# Shape after dropping columns: (82994, 19)
# Renamed columns:
#   'Product+Plan'  =>  'Product_Plan'
#
# Final Features for Model Training (16)
#
# Numerical Features (6):
#   - experian_rank_final
#   - variant_bracket_mapped
#   - cc_group_ordinal
#   - hit_flag_service
#   - personal_loan_flag
#   - embedded_red_flag
#
# Categorical Features (10):
#   - corrected_body_type
#   - fuel_type
#   - transmission_type
#   - city_mapped
#   - Product_Type2
#   - make_mapped
#   - cc_group
#   - customer_age_group
#   - Product_Plan
#   - recommended_idv_grouped
#
#  Feature Cardinality
# Features with the most unique values:
# make_mapped                19
# city_mapped                11
# experian_rank_final         6
# corrected_body_type         6
# recommended_idv_grouped     6
# cc_group_ordinal            4
# fuel_type                   4
# cc_group                    4
# customer_age_group          4
# variant_bracket_mapped      3
# hit_flag_service            2
# personal_loan_flag          2
# embedded_red_flag           2
# transmission_type           2
# Product_Type2               2
# Product_Plan                2
# dtype: int64

# %%
import matplotlib.pyplot as plt
import seaborn as sns

sns.set(style="whitegrid")

print("Filtering data from Jan 2022 to Apr 2025...")
analysis_start_date = '2022-01-01'
analysis_end_date = '2025-04-30'

df_cleaned['policy_start_date'] = pd.to_datetime(df_cleaned['policy_start_date'])

df_analysis_filtered = df_cleaned[
    (df_cleaned['policy_start_date'] >= analysis_start_date) &
    (df_cleaned['policy_start_date'] <= analysis_end_date)
].copy()

print(f"New shape: {df_analysis_filtered.shape}")
df_time = df_analysis_filtered.set_index('policy_start_date')

# Baseline Shift (P(y))
print("\n Baseline Shift (Overall Risk)")
q_baseline = df_time.resample('Q').agg(
actual_count=('od_claim_count', 'sum'),
exposure=('exposure', 'sum')
)
q_baseline = q_baseline[q_baseline['exposure'] > 0]
q_baseline['Actual IR'] = q_baseline['actual_count'] / q_baseline['exposure']

print(q_baseline[['Actual IR']])

plt.figure(figsize=(12, 6))
q_baseline['Actual IR'].plot(marker='o', linestyle='-')
plt.title('Baseline Shift (Overall Actual IR by Quarter)', fontsize=16)
plt.ylabel('Actual Incidence Rate (IR)')
plt.xlabel('Quarter')
plt.show()

# %%
# 2. Time-Based Data Splitting

TRAIN_START = '2022-01-01'
TRAIN_END = '2024-08-31'
TEST_START = '2024-09-01'
TEST_END = '2024-12-31'
OOT_START = '2025-01-01'
OOT_END = '2025-03-31'

# Create the sets
train_df = df_cleaned[
    (df_cleaned[DATE_COL] >= TRAIN_START) &
    (df_cleaned[DATE_COL] <= TRAIN_END)
].copy()

test_df = df_cleaned[
    (df_cleaned[DATE_COL] >= TEST_START) &
    (df_cleaned[DATE_COL] <= TEST_END)
].copy()

oot_df = df_cleaned[
    (df_cleaned[DATE_COL] >= OOT_START) &
    (df_cleaned[DATE_COL] <= OOT_END)
].copy()

print(f"  Train set shape: {train_df.shape} (Dates: {train_df[DATE_COL].min().date()} to {train_df[DATE_COL].max().date()})")
print(f"  Test set shape: {test_df.shape} (Dates: {test_df[DATE_COL].min().date()} to {test_df[DATE_COL].max().date()})")
print(f"  OOT set shape:   {oot_df.shape} (Dates: {oot_df[DATE_COL].min().date()} to {oot_df[DATE_COL].max().date()})")
# Out:
#   Train set shape: (50031, 19) (Dates: 2022-01-01 to 2024-08-31)
#   Test set shape: (8614, 19) (Dates: 2024-09-01 to 2024-12-31)
#   OOT set shape:   (5809, 19) (Dates: 2025-01-01 to 2025-03-31)

# %%
# 3. Model Training (LightGBM Poisson Regressor)

import optuna
import lightgbm as lgb
from sklearn.metrics import mean_poisson_deviance

# Prepare data splits
X_train, y_train, w_train = train_df[features], train_df[TARGET], train_df[WEIGHT]
X_test, y_test, w_test = test_df[features], test_df[TARGET], test_df[WEIGHT]
X_oot, y_oot, w_oot = oot_df[features], oot_df[TARGET], oot_df[WEIGHT]

# Define the Optuna objective function
def objective(trial):
    params = {
        'objective': 'poisson',
        'metric': 'poisson',
        'verbosity': -1,
        'boosting_type': 'gbdt',
        'n_jobs': -1,
        'seed': 42,
        'n_estimators': 1000, 
        'learning_rate': trial.suggest_float('learning_rate', 0.01, 0.1, log=True),
        'num_leaves': trial.suggest_int('num_leaves', 20, 60),
        'max_depth': trial.suggest_int('max_depth', 4, 10),
        'min_child_weight': trial.suggest_int('min_child_weight', 50, 200),
        'subsample': trial.suggest_float('subsample', 0.7, 1.0),
        'colsample_bytree': trial.suggest_float('colsample_bytree', 0.7, 1.0),
        'reg_alpha': trial.suggest_float('reg_alpha', 0.01, 1.0, log=True),
        'reg_lambda': trial.suggest_float('reg_lambda', 0.01, 1.0, log=True),
    }

    # Train model
    model = lgb.LGBMRegressor(**params)
    
    model.fit(
        X_train, y_train,
        sample_weight=w_train,
        eval_set=[(X_test, y_test)],
        eval_sample_weight=[w_test],
        eval_metric='poisson',
        callbacks=[lgb.early_stopping(150, verbose=False)],
        categorical_feature=categorical_features
    )
    
    
    return model.best_score_['valid_0']['poisson']

# Create and run Optuna study - want to minimize poisson deviance
study = optuna.create_study(direction='minimize')

# Start optimization. 
study.optimize(objective, n_trials=50, show_progress_bar=True)

# Get best parameters
print("\nOptuna study complete.")
print(f"Best trial (poisson): {study.best_value:.6f}")
print("Best parameters found:")
print(study.best_params)

# Train model with best parameters
best_params = study.best_params.copy()

final_lgb_params = {
    'objective': 'poisson',
    'metric': 'poisson',
    'verbosity': -1,
    'boosting_type': 'gbdt',
    'n_jobs': -1,
    'seed': 42,
    'n_estimators': 2000,
    **best_params 
}

print("\nTraining Final LightGBM model with best parameters...")
model = lgb.LGBMRegressor(**final_lgb_params)

model.fit(
    X_train, y_train,
    sample_weight=w_train,
    eval_set=[(X_test, y_test)],
    eval_sample_weight=[w_test],
    eval_metric='poisson',
    callbacks=[lgb.early_stopping(150, verbose=100)],
    categorical_feature=categorical_features
)

print("Model training complete.")

# Generate predictions
print("Generating predictions...")
pred_train = model.predict(X_train)
pred_test = model.predict(X_test)
pred_oot = model.predict(X_oot)

print("Predictions complete. You can now run your decile analysis.")
# Out:
# [I 2025-11-13 04:53:12,418] A new study created in memory with name: no-name-a0e41b4b-b723-460a-b2c1-d892d876d864
#   0%|          | 0/50 [00:00<?, ?it/s]
# [I 2025-11-13 04:53:12,960] Trial 0 finished with value: 0.6968784975536787 and parameters: {'learning_rate': 0.06340492055590749, 'num_leaves': 59, 'max_depth': 5, 'min_child_weight': 135, 'subsample': 0.9122653708617809, 'colsample_bytree': 0.8328357661496912, 'reg_alpha': 0.010982464043268194, 'reg_lambda': 0.010240302903876439}. Best is trial 0 with value: 0.6968784975536787.
# [I 2025-11-13 04:53:13,455] Trial 1 finished with value: 0.6984395693722747 and parameters: {'learning_rate': 0.05240122207346396, 'num_leaves': 49, 'max_depth': 7, 'min_child_weight': 53, 'subsample': 0.930452420808481, 'colsample_bytree': 0.9691841759698168, 'reg_alpha': 0.08457922176772015, 'reg_lambda': 0.25906375708427803}. Best is trial 0 with value: 0.6968784975536787.
# [I 2025-11-13 04:53:14,171] Trial 2 finished with value: 0.6982017594599189 and parameters: {'learning_rate': 0.03146452267705702, 'num_leaves': 58, 'max_depth': 7, 'min_child_weight': 128, 'subsample': 0.8590929646416892, 'colsample_bytree': 0.9031649880828834, 'reg_alpha': 0.11862893538204182, 'reg_lambda': 0.9581104853683576}. Best is trial 0 with value: 0.6968784975536787.
# [I 2025-11-13 04:53:14,768] Trial 3 finished with value: 0.6982808250506507 and parameters: {'learning_rate': 0.06329594637358706, 'num_leaves': 52, 'max_depth': 9, 'min_child_weight': 194, 'subsample': 0.9706323642874517, 'colsample_bytree': 0.9593647747161456, 'reg_alpha': 0.06780974403069294, 'reg_lambda': 0.09893261774226449}. Best is trial 0 with value: 0.6968784975536787.
# [I 2025-11-13 04:53:15,729] Trial 4 finished with value: 0.6960354832213 and parameters: {'learning_rate': 0.01488063505830452, 'num_leaves': 31, 'max_depth': 4, 'min_child_weight': 111, 'subsample': 0.9151980671009101, 'colsample_bytree': 0.9977911086026576, 'reg_alpha': 0.04871624722067872, 'reg_lambda': 0.5825532583395232}. Best is trial 4 with value: 0.6960354832213.
# [I 2025-11-13 04:53:17,191] Trial 5 finished with value: 0.6977306294195017 and parameters: {'learning_rate': 0.01166038394440729, 'num_leaves': 50, 'max_depth': 6, 'min_child_weight': 101, 'subsample': 0.7287530827960805, 'colsample_bytree': 0.9052238181302249, 'reg_alpha': 0.015165495639278383, 'reg_lambda': 0.12299568489344906}. Best is trial 4 with value: 0.6960354832213.
# [I 2025-11-13 04:53:18,333] Trial 6 finished with value: 0.6959255630590028 and parameters: {'learning_rate': 0.02005973395018099, 'num_leaves': 58, 'max_depth': 4, 'min_child_weight': 164, 'subsample': 0.781439499000103, 'colsample_bytree': 0.8409894216163472, 'reg_alpha': 0.037330876777779104, 'reg_lambda': 0.01539022698921113}. Best is trial 6 with value: 0.6959255630590028.
# [I 2025-11-13 04:53:18,955] Trial 7 finished with value: 0.6982414220024771 and parameters: {'learning_rate': 0.09003431936424308, 'num_leaves': 54, 'max_depth': 10, 'min_child_weight': 184, 'subsample': 0.7762080113222416, 'colsample_bytree': 0.8055661746120368, 'reg_alpha': 0.010075119914096486, 'reg_lambda': 0.16433419146512343}. Best is trial 6 with value: 0.6959255630590028.
# [I 2025-11-13 04:53:20,762] Trial 8 finished with value: 0.6979702515041944 and parameters: {'learning_rate': 0.013214516804104879, 'num_leaves': 60, 'max_depth': 7, 'min_child_weight': 134, 'subsample': 0.9823152852681226, 'colsample_bytree': 0.8133554035843643, 'reg_alpha': 0.06324558177087021, 'reg_lambda': 0.033686517158218396}. Best is trial 6 with value: 0.6959255630590028.
# [I 2025-11-13 04:53:22,201] Trial 9 finished with value: 0.6968077640277344 and parameters: {'learning_rate': 0.011236099594619875, 'num_leaves': 45, 'max_depth': 5, 'min_child_weight': 166, 'subsample': 0.7990323151900018, 'colsample_bytree': 0.950984069430342, 'reg_alpha': 0.09843345819581446, 'reg_lambda': 0.07970395728684376}. Best is trial 6 with value: 0.6959255630590028.
# [I 2025-11-13 04:53:23,270] Trial 10 finished with value: 0.6963526286732267 and parameters: {'learning_rate': 0.026885754868135804, 'num_leaves': 22, 'max_depth': 4, 'min_child_weight': 156, 'subsample': 0.7017035669799246, 'colsample_bytree': 0.7069454202495435, 'reg_alpha': 0.6234256345761968, 'reg_lambda': 0.01012680383396747}. Best is trial 6 with value: 0.6959255630590028.
# [I 2025-11-13 04:53:24,282] Trial 11 finished with value: 0.6959530535494921 and parameters: {'learning_rate': 0.01928553762999746, 'num_leaves': 33, 'max_depth': 4, 'min_child_weight': 97, 'subsample': 0.8513617845586022, 'colsample_bytree': 0.7608436506145939, 'reg_alpha': 0.031866344728670636, 'reg_lambda': 0.8476796452721149}. Best is trial 6 with value: 0.6959255630590028.
# [I 2025-11-13 04:53:25,284] Trial 12 finished with value: 0.6960223590693035 and parameters: {'learning_rate': 0.020694401923375703, 'num_leaves': 36, 'max_depth': 4, 'min_child_weight': 81, 'subsample': 0.8357963986057837, 'colsample_bytree': 0.7318484925226663, 'reg_alpha': 0.029676388919368607, 'reg_lambda': 0.033736538183813225}. Best is trial 6 with value: 0.6959255630590028.
# [I 2025-11-13 04:53:26,735] Trial 13 finished with value: 0.6967863405923462 and parameters: {'learning_rate': 0.019350516947109556, 'num_leaves': 30, 'max_depth': 5, 'min_child_weight': 79, 'subsample': 0.852660579605362, 'colsample_bytree': 0.7653479049275826, 'reg_alpha': 0.24080955627210862, 'reg_lambda': 0.02996136862634632}. Best is trial 6 with value: 0.6959255630590028.
# [I 2025-11-13 04:53:28,846] Trial 14 finished with value: 0.6968634705285315 and parameters: {'learning_rate': 0.021187444982256536, 'num_leaves': 40, 'max_depth': 6, 'min_child_weight': 158, 'subsample': 0.7701263581813084, 'colsample_bytree': 0.776919584986346, 'reg_alpha': 0.028326745391911778, 'reg_lambda': 0.38703043890844496}. Best is trial 6 with value: 0.6959255630590028.
# [I 2025-11-13 04:53:30,220] Trial 15 finished with value: 0.6968661271640777 and parameters: {'learning_rate': 0.03560684757838779, 'num_leaves': 26, 'max_depth': 9, 'min_child_weight': 88, 'subsample': 0.8140294496731737, 'colsample_bytree': 0.8814127180853558, 'reg_alpha': 0.02857770989171558, 'reg_lambda': 0.058929670197045446}. Best is trial 6 with value: 0.6959255630590028.
# [I 2025-11-13 04:53:32,756] Trial 16 finished with value: 0.6973025687021124 and parameters: {'learning_rate': 0.01634569519998611, 'num_leaves': 43, 'max_depth': 6, 'min_child_weight': 54, 'subsample': 0.8831133956140705, 'colsample_bytree': 0.8515302072528523, 'reg_alpha': 0.1972299011280259, 'reg_lambda': 0.01813344156217492}. Best is trial 6 with value: 0.6959255630590028.
# [I 2025-11-13 04:53:34,598] Trial 17 finished with value: 0.6960757616470553 and parameters: {'learning_rate': 0.025349623197937175, 'num_leaves': 36, 'max_depth': 4, 'min_child_weight': 178, 'subsample': 0.7636841966296174, 'colsample_bytree': 0.7631435562831603, 'reg_alpha': 0.02222252528142881, 'reg_lambda': 0.2365812297652816}. Best is trial 6 with value: 0.6959255630590028.
# [I 2025-11-13 04:53:35,710] Trial 18 finished with value: 0.696702887098313 and parameters: {'learning_rate': 0.03921219825966436, 'num_leaves': 20, 'max_depth': 5, 'min_child_weight': 147, 'subsample': 0.7359748968927756, 'colsample_bytree': 0.8594119150565452, 'reg_alpha': 0.04644872924937128, 'reg_lambda': 0.9795198525638776}. Best is trial 6 with value: 0.6959255630590028.
# [I 2025-11-13 04:53:38,079] Trial 19 finished with value: 0.6972531254609958 and parameters: {'learning_rate': 0.016202611238521566, 'num_leaves': 35, 'max_depth': 8, 'min_child_weight': 111, 'subsample': 0.8127345420613405, 'colsample_bytree': 0.7970295176863612, 'reg_alpha': 0.17205618882719964, 'reg_lambda': 0.054208368389887435}. Best is trial 6 with value: 0.6959255630590028.
# [I 2025-11-13 04:53:40,906] Trial 20 finished with value: 0.6974641123957388 and parameters: {'learning_rate': 0.01013920687156828, 'num_leaves': 45, 'max_depth': 6, 'min_child_weight': 66, 'subsample': 0.8781630654961444, 'colsample_bytree': 0.7365029789864521, 'reg_alpha': 0.4260122047654488, 'reg_lambda': 0.4921604524971216}. Best is trial 6 with value: 0.6959255630590028.
# [I 2025-11-13 04:53:42,695] Trial 21 finished with value: 0.6961193684422661 and parameters: {'learning_rate': 0.021443960804266547, 'num_leaves': 37, 'max_depth': 4, 'min_child_weight': 87, 'subsample': 0.8292035190225437, 'colsample_bytree': 0.7139649891092427, 'reg_alpha': 0.03430220965369211, 'reg_lambda': 0.026582893659874287}. Best is trial 6 with value: 0.6959255630590028.
# [I 2025-11-13 04:53:44,388] Trial 22 finished with value: 0.6960425600830722 and parameters: {'learning_rate': 0.025597999108327593, 'num_leaves': 31, 'max_depth': 4, 'min_child_weight': 104, 'subsample': 0.8358342248707099, 'colsample_bytree': 0.7380199947117898, 'reg_alpha': 0.01597091844529106, 'reg_lambda': 0.020225325313472306}. Best is trial 6 with value: 0.6959255630590028.
# [I 2025-11-13 04:53:46,657] Trial 23 finished with value: 0.696671329299443 and parameters: {'learning_rate': 0.0198372919677247, 'num_leaves': 40, 'max_depth': 5, 'min_child_weight': 77, 'subsample': 0.7921652706106086, 'colsample_bytree': 0.7404021482357482, 'reg_alpha': 0.018732932317290972, 'reg_lambda': 0.015116152560397663}. Best is trial 6 with value: 0.6959255630590028.
# [I 2025-11-13 04:53:48,684] Trial 24 finished with value: 0.696037882073924 and parameters: {'learning_rate': 0.018269237211329836, 'num_leaves': 27, 'max_depth': 4, 'min_child_weight': 119, 'subsample': 0.8792131865442305, 'colsample_bytree': 0.7782615468813343, 'reg_alpha': 0.03350348516657693, 'reg_lambda': 0.05135704589880622}. Best is trial 6 with value: 0.6959255630590028.
# [I 2025-11-13 04:53:50,516] Trial 25 finished with value: 0.6967899386465382 and parameters: {'learning_rate': 0.028143622659946518, 'num_leaves': 35, 'max_depth': 5, 'min_child_weight': 95, 'subsample': 0.8387689742472321, 'colsample_bytree': 0.8246426922423564, 'reg_alpha': 0.04865354858045867, 'reg_lambda': 0.03863805778222017}. Best is trial 6 with value: 0.6959255630590028.
# [I 2025-11-13 04:53:52,456] Trial 26 finished with value: 0.6964024787255881 and parameters: {'learning_rate': 0.013820977832390823, 'num_leaves': 33, 'max_depth': 4, 'min_child_weight': 69, 'subsample': 0.8104953642598791, 'colsample_bytree': 0.7232635258715922, 'reg_alpha': 0.023833617316833474, 'reg_lambda': 0.02316649283091872}. Best is trial 6 with value: 0.6959255630590028.
# [I 2025-11-13 04:53:53,544] Trial 27 finished with value: 0.6966528588018434 and parameters: {'learning_rate': 0.04352814830911373, 'num_leaves': 40, 'max_depth': 5, 'min_child_weight': 145, 'subsample': 0.8641285874783511, 'colsample_bytree': 0.7519239063739112, 'reg_alpha': 0.042717381425315615, 'reg_lambda': 0.014486229093231143}. Best is trial 6 with value: 0.6959255630590028.
# [I 2025-11-13 04:53:55,180] Trial 28 finished with value: 0.6960047454562512 and parameters: {'learning_rate': 0.02418012579329831, 'num_leaves': 27, 'max_depth': 4, 'min_child_weight': 116, 'subsample': 0.7458640468856629, 'colsample_bytree': 0.794496778003613, 'reg_alpha': 0.015171094033527724, 'reg_lambda': 0.014157823769276079}. Best is trial 6 with value: 0.6959255630590028.
# [I 2025-11-13 04:53:56,637] Trial 29 finished with value: 0.6968948428949383 and parameters: {'learning_rate': 0.032018975026024264, 'num_leaves': 26, 'max_depth': 5, 'min_child_weight': 120, 'subsample': 0.7447286821747443, 'colsample_bytree': 0.8358927482351272, 'reg_alpha': 0.013982536682481035, 'reg_lambda': 0.0126477118121962}. Best is trial 6 with value: 0.6959255630590028.
# [I 2025-11-13 04:53:58,819] Trial 30 finished with value: 0.6964036660134104 and parameters: {'learning_rate': 0.02413326881253746, 'num_leaves': 23, 'max_depth': 6, 'min_child_weight': 142, 'subsample': 0.7091225316439619, 'colsample_bytree': 0.7861768476841654, 'reg_alpha': 0.011721836548759213, 'reg_lambda': 0.17009657303747025}. Best is trial 6 with value: 0.6959255630590028.
# [I 2025-11-13 04:54:00,678] Trial 31 finished with value: 0.6957758182760848 and parameters: {'learning_rate': 0.022344664253831265, 'num_leaves': 27, 'max_depth': 4, 'min_child_weight': 92, 'subsample': 0.7503721305696993, 'colsample_bytree': 0.833363928605767, 'reg_alpha': 0.0241803278476462, 'reg_lambda': 0.01158163312151978}. Best is trial 31 with value: 0.6957758182760848.
# [I 2025-11-13 04:54:02,381] Trial 32 finished with value: 0.6960079030167377 and parameters: {'learning_rate': 0.01728808150251043, 'num_leaves': 28, 'max_depth': 4, 'min_child_weight': 98, 'subsample': 0.7535053112927774, 'colsample_bytree': 0.836964001228067, 'reg_alpha': 0.018495756940699895, 'reg_lambda': 0.010524954848796004}. Best is trial 31 with value: 0.6957758182760848.
# [I 2025-11-13 04:54:03,806] Trial 33 finished with value: 0.6969293977317799 and parameters: {'learning_rate': 0.031646156136999434, 'num_leaves': 57, 'max_depth': 5, 'min_child_weight': 130, 'subsample': 0.7229579332593221, 'colsample_bytree': 0.8736307314675091, 'reg_alpha': 0.02110238066890237, 'reg_lambda': 0.018484594581784124}. Best is trial 31 with value: 0.6957758182760848.
# [I 2025-11-13 04:54:05,634] Trial 34 finished with value: 0.6959636442537732 and parameters: {'learning_rate': 0.02286310354213983, 'num_leaves': 24, 'max_depth': 4, 'min_child_weight': 111, 'subsample': 0.7827570183799071, 'colsample_bytree': 0.8145054392811123, 'reg_alpha': 0.06828529079933242, 'reg_lambda': 0.014592055654820274}. Best is trial 31 with value: 0.6957758182760848.
# [I 2025-11-13 04:54:07,475] Trial 35 finished with value: 0.6957566285146514 and parameters: {'learning_rate': 0.02241567397096404, 'num_leaves': 23, 'max_depth': 4, 'min_child_weight': 92, 'subsample': 0.7861169138319849, 'colsample_bytree': 0.8980240889660359, 'reg_alpha': 0.07178480360722005, 'reg_lambda': 0.6224667750737121}. Best is trial 35 with value: 0.6957566285146514.
# [I 2025-11-13 04:54:09,802] Trial 36 finished with value: 0.6969329409432194 and parameters: {'learning_rate': 0.014580305351048435, 'num_leaves': 29, 'max_depth': 8, 'min_child_weight': 89, 'subsample': 0.9068920141699232, 'colsample_bytree': 0.9285108239885385, 'reg_alpha': 0.12325587519238934, 'reg_lambda': 0.686014422057406}. Best is trial 35 with value: 0.6957566285146514.
# [I 2025-11-13 04:54:11,120] Trial 37 finished with value: 0.6967245302742411 and parameters: {'learning_rate': 0.028536388595037158, 'num_leaves': 33, 'max_depth': 5, 'min_child_weight': 200, 'subsample': 0.9345722015776037, 'colsample_bytree': 0.903506408544546, 'reg_alpha': 0.0748042976873184, 'reg_lambda': 0.36956062333744244}. Best is trial 35 with value: 0.6957566285146514.
# [I 2025-11-13 04:54:12,206] Trial 38 finished with value: 0.695783736498722 and parameters: {'learning_rate': 0.045832286539653426, 'num_leaves': 24, 'max_depth': 4, 'min_child_weight': 64, 'subsample': 0.7618520148373292, 'colsample_bytree': 0.9273205419698394, 'reg_alpha': 0.056488033746896024, 'reg_lambda': 0.7441054939594947}. Best is trial 35 with value: 0.6957566285146514.
# [I 2025-11-13 04:54:12,989] Trial 39 finished with value: 0.6968903095001812 and parameters: {'learning_rate': 0.05708492984652998, 'num_leaves': 21, 'max_depth': 5, 'min_child_weight': 54, 'subsample': 0.7606505280072257, 'colsample_bytree': 0.9336372092197777, 'reg_alpha': 0.12410949375041916, 'reg_lambda': 0.29008590602874174}. Best is trial 35 with value: 0.6957566285146514.
# [I 2025-11-13 04:54:13,774] Trial 40 finished with value: 0.6971396241351415 and parameters: {'learning_rate': 0.04868316995053237, 'num_leaves': 25, 'max_depth': 8, 'min_child_weight': 65, 'subsample': 0.7853012662273657, 'colsample_bytree': 0.9824384851346161, 'reg_alpha': 0.06058695951793978, 'reg_lambda': 0.6303779443632431}. Best is trial 35 with value: 0.6957566285146514.
# [I 2025-11-13 04:54:14,596] Trial 41 finished with value: 0.6959808110711487 and parameters: {'learning_rate': 0.06696357776203987, 'num_leaves': 23, 'max_depth': 4, 'min_child_weight': 72, 'subsample': 0.7240418949946844, 'colsample_bytree': 0.8846157545657927, 'reg_alpha': 0.038561901631009844, 'reg_lambda': 0.8085296023139468}. Best is trial 35 with value: 0.6957566285146514.
# [I 2025-11-13 04:54:15,317] Trial 42 finished with value: 0.6954989716705235 and parameters: {'learning_rate': 0.08815417700775369, 'num_leaves': 49, 'max_depth': 4, 'min_child_weight': 105, 'subsample': 0.7962128524141348, 'colsample_bytree': 0.9222255318625723, 'reg_alpha': 0.09158588774988265, 'reg_lambda': 0.4610807517259258}. Best is trial 42 with value: 0.6954989716705235.
# [I 2025-11-13 04:54:16,079] Trial 43 finished with value: 0.6957941008182202 and parameters: {'learning_rate': 0.05735292906347222, 'num_leaves': 52, 'max_depth': 4, 'min_child_weight': 105, 'subsample': 0.7995094155624202, 'colsample_bytree': 0.9219957207037875, 'reg_alpha': 0.08327842900293624, 'reg_lambda': 0.492153822767996}. Best is trial 42 with value: 0.6954989716705235.
# [I 2025-11-13 04:54:16,767] Trial 44 finished with value: 0.6959423887454571 and parameters: {'learning_rate': 0.099463054022974, 'num_leaves': 55, 'max_depth': 4, 'min_child_weight': 105, 'subsample': 0.8057521345347918, 'colsample_bytree': 0.9222369144077944, 'reg_alpha': 0.08997763244806756, 'reg_lambda': 0.49134966861716395}. Best is trial 42 with value: 0.6954989716705235.
# [I 2025-11-13 04:54:17,506] Trial 45 finished with value: 0.6977223342720261 and parameters: {'learning_rate': 0.08278695423717311, 'num_leaves': 50, 'max_depth': 10, 'min_child_weight': 60, 'subsample': 0.7724983862566169, 'colsample_bytree': 0.9518740407910429, 'reg_alpha': 0.14902722379740532, 'reg_lambda': 0.4662000949663816}. Best is trial 42 with value: 0.6954989716705235.
# [I 2025-11-13 04:54:18,268] Trial 46 finished with value: 0.6980494596032678 and parameters: {'learning_rate': 0.06582989273263933, 'num_leaves': 48, 'max_depth': 7, 'min_child_weight': 92, 'subsample': 0.7944043401050866, 'colsample_bytree': 0.9134514803076472, 'reg_alpha': 0.05821492975779151, 'reg_lambda': 0.29884289903682487}. Best is trial 42 with value: 0.6954989716705235.
# [I 2025-11-13 04:54:18,980] Trial 47 finished with value: 0.6956759043076776 and parameters: {'learning_rate': 0.05781878603557567, 'num_leaves': 47, 'max_depth': 4, 'min_child_weight': 82, 'subsample': 0.7509906051650248, 'colsample_bytree': 0.938152037701878, 'reg_alpha': 0.0833002350495058, 'reg_lambda': 0.20750759010558603}. Best is trial 42 with value: 0.6954989716705235.
# [I 2025-11-13 04:54:19,615] Trial 48 finished with value: 0.696835713019595 and parameters: {'learning_rate': 0.07627391857322652, 'num_leaves': 48, 'max_depth': 5, 'min_child_weight': 78, 'subsample': 0.7381610678357832, 'colsample_bytree': 0.9747744346985209, 'reg_alpha': 0.30535200864606205, 'reg_lambda': 0.12969634579740658}. Best is trial 42 with value: 0.6954989716705235.
# [I 2025-11-13 04:54:20,725] Trial 49 finished with value: 0.695998676656862 and parameters: {'learning_rate': 0.04819784083670871, 'num_leaves': 46, 'max_depth': 4, 'min_child_weight': 84, 'subsample': 0.7553363441997716, 'colsample_bytree': 0.8922134259681463, 'reg_alpha': 0.05415734701966995, 'reg_lambda': 0.20156098739757602}. Best is trial 42 with value: 0.6954989716705235.
#
# Optuna study complete.
# Best trial (poisson): 0.695499
# Best parameters found:
# {'learning_rate': 0.08815417700775369, 'num_leaves': 49, 'max_depth': 4, 'min_child_weight': 105, 'subsample': 0.7962128524141348, 'colsample_bytree': 0.9222255318625723, 'reg_alpha': 0.09158588774988265, 'reg_lambda': 0.4610807517259258}
#
# Training Final LightGBM model with best parameters...
# Training until validation scores don't improve for 150 rounds
# Early stopping, best iteration is:
# [290]	valid_0's poisson: 0.695499
# Model training complete.
# Generating predictions...
# Predictions complete. You can now run your decile analysis.

# %%
# 4. Decile Analysis Function
def create_decline_analysis(y_true, y_pred_count, exposure, set_name):
    print(f"\n Decile Analysis: {set_name} Set")
    
    eval_df = pd.DataFrame({
        'actual_count': y_true,
        'predicted_count': y_pred_count,
        'exposure': exposure
    })
    eval_df = eval_df[eval_df['exposure'] > 0].copy()

    overall_actual_ir = eval_df['actual_count'].sum() / eval_df['exposure'].sum()
    overall_pred_ir = eval_df['predicted_count'].sum() / eval_df['exposure'].sum()
    
    # Binning based on the raw predicted count
    eval_df['decile'] = pd.qcut(eval_df['predicted_count'], 10, labels=False, duplicates='drop')


    decile_groups = eval_df.groupby('decile')
    
    decile_summary = pd.DataFrame({
        'Policies': decile_groups.size(),
        'Total Exposure': decile_groups['exposure'].sum(),
        'Actual Claims': decile_groups['actual_count'].sum(),
        'Predicted IR': decile_groups['predicted_count'].mean() 
    })
    
    decile_summary['Actual IR'] = decile_summary['Actual Claims'] / decile_summary['Total Exposure']
    decile_summary['Delta'] = (decile_summary['Predicted IR'] / decile_summary['Actual IR']) - 1

    if overall_actual_ir > 0:
        decile_summary['Lift'] = decile_summary['Actual IR'] / overall_actual_ir
    else:
        decile_summary['Lift'] = np.nan
        
    top_decile_lift = np.nan
    top_to_bottom_ratio = np.nan
    
    if 9 in decile_summary.index:
        top_decile_lift = decile_summary.loc[9, 'Lift']
        top_decile_ir = decile_summary.loc[9, 'Actual IR']
        if 0 in decile_summary.index:
            bottom_decile_ir = decile_summary.loc[0, 'Actual IR']
            if bottom_decile_ir > 0:
                top_to_bottom_ratio = top_decile_ir / bottom_decile_ir


    format_cols_pct = ['Actual IR', 'Predicted IR', 'Delta']
    for col in format_cols_pct:
        decile_summary[col] = (decile_summary[col] * 100).map('{:,.2f}%'.format)

    decile_summary['Lift'] = decile_summary['Lift'].map('{:,.2f}'.format)

    display_cols = ['Policies', 'Actual IR', 'Predicted IR', 'Delta']
    print(decile_summary[display_cols])
    
    print(f"\nOverall Actual IR:    {overall_actual_ir:.4%}")
    print(f"Overall Predicted IR: {overall_pred_ir:.4%}")
    
    print(f"Lift:  {top_to_bottom_ratio:.2f}x")
    

# 5. Run Analysis & Report
create_decline_analysis(y_train, pred_train, w_train, "Train")
create_decline_analysis(y_test, pred_test, w_test, "Test")
create_decline_analysis(y_oot, pred_oot, w_oot, "OOT")
# Out:
#  Decile Analysis: Train Set
#         Policies Actual IR Predicted IR    Delta
# decile
# 0           5004    18.05%       21.71%   20.32%
# 1           5005    25.54%       28.72%   12.45%
# 2           5001    30.24%       32.07%    6.06%
# 3           5003    33.46%       34.93%    4.40%
# 4           5003    37.03%       37.71%    1.84%
# 5           5003    40.59%       40.73%    0.34%
# 6           5003    42.94%       44.14%    2.80%
# 7           5003    49.21%       48.61%   -1.23%
# 8           5003    57.98%       54.78%   -5.51%
# 9           5003    78.46%       70.59%  -10.04%
#
# Overall Actual IR:    41.3488%
# Overall Predicted IR: 41.3493%
# Lift:  4.35x
#
#  Decile Analysis: Test Set
#         Policies Actual IR Predicted IR   Delta
# decile
# 0            862    22.30%       20.35%  -8.74%
# 1            861    27.01%       27.32%   1.13%
# 2            862    32.24%       30.95%  -4.00%
# 3            861    32.01%       33.83%   5.66%
# 4            861    32.68%       36.72%  12.37%
# 5            861    35.82%       39.78%  11.07%
# 6            862    38.75%       43.04%  11.07%
# 7            861    41.62%       47.45%  14.00%
# 8            861    48.91%       52.99%   8.35%
# 9            862    64.38%       68.75%   6.79%
#
# Overall Actual IR:    37.5536%
# Overall Predicted IR: 45.1090%
# Lift:  2.89x
#
#  Decile Analysis: OOT Set
#         Policies Actual IR Predicted IR    Delta
# decile
# 0            581    26.32%       21.18%  -19.50%
# 1            582    31.26%       28.12%  -10.05%
# 2            580    28.24%       31.69%   12.21%
# 3            581    28.94%       34.71%   19.94%
# 4            581    36.57%       37.50%    2.54%
# 5            580    36.41%       40.64%   11.64%
# 6            581    42.51%       44.12%    3.80%
# 7            581    43.93%       48.04%    9.36%
# 8            581    52.62%       53.93%    2.48%
# 9            581    61.10%       72.04%   17.90%
#
# Overall Actual IR:    38.7561%
# Overall Predicted IR: 66.1530%
# Lift:  2.32x

# %%
# 6. Post-Model Analysis
def create_feature_level_analysis(X_data, y_true, y_pred_count, exposure, model, set_name):

    print(f"\n Feature-Level Analysis: {set_name} Set")
    
    eval_df = X_data.copy()
    eval_df['actual_count'] = y_true
    eval_df['predicted_count'] = y_pred_count
    eval_df['exposure'] = exposure
    
    eval_df = eval_df[eval_df['exposure'] > 0].copy()
        
    try:
        top_features = model.booster_.feature_name()[:25]
        print(f"Analyzing features: {top_features}")
    except Exception as e:
        print(f"Couldn't get feature names, skipping: {e}")
        return

    for col in top_features:
        if col not in eval_df.columns:
            print(f"Skipping '{col}', not in X_data.")
            continue
            
        print(f"\nAnalyzing Feature: '{col}'")
        
        feature_data = eval_df[col]
        if feature_data.isnull().any():
            if feature_data.dtype.name == 'category':
                feature_data = feature_data.cat.add_categories('NaN').fillna('NaN')
            else:
                feature_data = feature_data.fillna('NaN')
                
        groups = eval_df.groupby(feature_data)
        
        summary_df = pd.DataFrame({
            'Policies': groups.size(),
            'Total Exposure': groups['exposure'].sum(),
            'Actual Claims': groups['actual_count'].sum(),
            'Predicted Claims': groups['predicted_count'].sum()
        })
        
        summary_df['Actual IR'] = summary_df['Actual Claims'] / summary_df['Total Exposure']
        summary_df['Predicted IR'] = summary_df['Predicted Claims'] / summary_df['Total Exposure']
        summary_df['Delta'] = summary_df['Actual IR'] - summary_df['Predicted IR']
        
        summary_df = summary_df.sort_values(by='Policies', ascending=False)
        
        format_cols_pct = ['Actual IR', 'Predicted IR', 'Delta']
        for pct_col in format_cols_pct:
            summary_df[pct_col] = (summary_df[pct_col] * 100).map('{:,.2f}%'.format)

        with pd.option_context('display.max_rows', 25):
             print(summary_df[['Policies', 'Actual IR', 'Predicted IR', 'Delta']].head(25))
        
        if len(summary_df) > 20:
            print(f"  ... (and {len(summary_df) - 20} more values)")

# Run analysis on OOT set
print("\n Feature-Level Analysis on OOT Set...")
create_feature_level_analysis(
    X_oot, 
    y_oot, 
    pred_oot, 
    w_oot, 
    model, 
    "OOT"
)

# %%
import pandas as pd

def get_summary_stats(y_true, y_pred_count, exposure, set_name):
    """Calculates summary stats for a given dataset."""
    
    # Filter out records with no exposure, matching your decile function
    mask = exposure > 0
    y_true_filtered = y_true[mask]
    y_pred_count_filtered = y_pred_count[mask]
    exposure_filtered = exposure[mask]

    # Calculate total sums
    total_exposure = exposure_filtered.sum()
    actual_claims = y_true_filtered.sum()
    predicted_claims = y_pred_count_filtered.sum() 
    
    # Calculate overall rates
    actual_ir = (actual_claims / total_exposure)
    predicted_ir = (predicted_claims / total_exposure)
    
    return {
        'Set': set_name,
        'Total Exposure': total_exposure,
        'Actual Claims': actual_claims,
        'Predicted Claims': predicted_claims,
        'Actual IR': actual_ir,
        'Predicted IR': predicted_ir
    }

# --- Run Calculations ---
# Assumes y_train, pred_train, w_train, etc., are in memory
summary_list = []
summary_list.append(get_summary_stats(y_train, pred_train, w_train, "Train"))
summary_list.append(get_summary_stats(y_test, pred_test, w_test, "Test"))
summary_list.append(get_summary_stats(y_oot, pred_oot, w_oot, "OOT"))

# --- Create and Display the DataFrame ---
summary_df = pd.DataFrame(summary_list).set_index('Set')

# Define formatting
formatters = {
    'Total Exposure': '{:,.2f}'.format,
    'Actual Claims': '{:,.0f}'.format,
    'Predicted Claims': '{:,.2f}'.format,
    'Actual IR': '{:.4%}'.format,
    'Predicted IR': '{:.4%}'.format
}

print("--- Model Performance Summary ---")
# Use to_string() to ensure all formatters apply
print(summary_df.to_string(formatters=formatters))
# Out:
# --- Model Performance Summary ---
#       Total Exposure Actual Claims Predicted Claims Actual IR Predicted IR
# Set
# Train      50,090.90        20,712        20,712.25  41.3488%     41.3493%
# Test        7,661.04         2,877         3,455.82  37.5536%     45.1090%
# OOT         3,617.49         1,402         2,393.08  38.7561%     66.1530%
